# %% [markdown]
# ## Cleaning dataset

# %% [markdown]
# -Importing dataset(2003-2007) and libraries

# %%
# !pip install pandas
# !pip install numpy
import math
import numpy as np 
import pandas as pd

# %%
#Importing dataset 
Y2003 = pd.read_csv("C:/Users/Admin/Desktop/ST2195_Programming_for_datascience/Coursework/dataset/2003_old.csv", encoding='latin-1', low_memory= False)
Y2004 = pd.read_csv("C:/Users/Admin/Desktop/ST2195_Programming_for_datascience/Coursework/dataset/2004_old.csv", encoding='latin-1', low_memory= False)
Y2005 = pd.read_csv("C:/Users/Admin/Desktop/ST2195_Programming_for_datascience/Coursework/dataset/2005_old.csv", encoding='latin-1', low_memory= False)
Y2006 = pd.read_csv("C:/Users/Admin/Desktop/ST2195_Programming_for_datascience/Coursework/dataset/2006_old.csv", encoding='latin-1', low_memory= False)
Y2007 = pd.read_csv("C:/Users/Admin/Desktop/ST2195_Programming_for_datascience/Coursework/dataset/2007_old.csv", encoding='latin-1', low_memory= False)

# %%
Y2003.describe
# Out:
# <bound method NDFrame.describe of          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0        2003      1          29          3   1651.0        1655   1912.0
# 1        2003      1          30          4   1654.0        1655   1910.0
# 2        2003      1          31          5   1724.0        1655   1936.0
# 3        2003      1           1          3   1033.0        1035   1625.0
# 4        2003      1           2          4   1053.0        1035   1726.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 6488535  2003     12           5          5   1126.0        1110   1326.0
# 6488536  2003     12           5          5   2100.0        2010   2240.0
# 6488537  2003     12           5          5   1142.0        1145   1217.0
# 6488538  2003     12           5          5    623.0         620    911.0
# 6488539  2003     12           5          5   1024.0        1025   1626.0
#
# ...

# %%
Y2003.isnull().sum()
# Out:
# Year                       0
# Month                      0
# DayofMonth                 0
# DayOfWeek                  0
# DepTime               101469
# CRSDepTime                 0
# ArrTime               112850
# CRSArrTime                 0
# UniqueCarrier              0
# FlightNum                  0
# TailNum                26336
# ActualElapsedTime     112851
# CRSElapsedTime             1
# AirTime               112850
# ArrDelay              112851
# DepDelay              101469
# Origin                     0
# Dest                       0
# Distance                   0
# TaxiIn                     0
# TaxiOut                    0
# Cancelled                  0
# CancellationCode     6435446
# Diverted                   0
# CarrierDelay         2672742
# WeatherDelay         2672742
# NASDelay             2672742
# SecurityDelay        2672742
# LateAircraftDelay    2672742
# dtype: int64

# %%
Y2003.describe()
# Out:
#             Year         Month    DayofMonth     DayOfWeek       DepTime  \
# count  6488540.0  6.488540e+06  6.488540e+06  6.488540e+06  6.387071e+06
# mean      2003.0  6.525727e+00  1.571836e+01  3.930434e+00  1.344690e+03
# std          0.0  3.450800e+00  8.778332e+00  1.988876e+00  4.655073e+02
# min       2003.0  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%       2003.0  4.000000e+00  8.000000e+00  2.000000e+00  9.400000e+02
# 50%       2003.0  7.000000e+00  1.600000e+01  4.000000e+00  1.330000e+03
# 75%       2003.0  1.000000e+01  2.300000e+01  6.000000e+00  1.730000e+03
# max       2003.0  1.200000e+01  3.100000e+01  7.000000e+00  2.735000e+03
#
#          CRSDepTime       ArrTime    CRSArrTime     FlightNum  \
# count  6.488540e+06  6.375690e+06  6.488540e+06  6.488540e+06
# mean   1.341220e+03  1.504361e+03  1.510046e+03  2.013294e+03
# std    4.574301e+02  4.820910e+02  4.693388e+02  1.937488e+03
# ...

# %%
Y2003
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0        2003      1          29          3   1651.0        1655   1912.0
# 1        2003      1          30          4   1654.0        1655   1910.0
# 2        2003      1          31          5   1724.0        1655   1936.0
# 3        2003      1           1          3   1033.0        1035   1625.0
# 4        2003      1           2          4   1053.0        1035   1726.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 6488535  2003     12           5          5   1126.0        1110   1326.0
# 6488536  2003     12           5          5   2100.0        2010   2240.0
# 6488537  2003     12           5          5   1142.0        1145   1217.0
# 6488538  2003     12           5          5    623.0         620    911.0
# 6488539  2003     12           5          5   1024.0        1025   1626.0
#
#          CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
Y2004
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0        2004      1          12          1    623.0         630    901.0
# 1        2004      1          13          2    621.0         630    911.0
# 2        2004      1          14          3    633.0         630    920.0
# 3        2004      1          15          4    627.0         630    859.0
# 4        2004      1          16          5    635.0         630    918.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 7129265  2004     12          16          4   1645.0        1639   1715.0
# 7129266  2004     12          16          4    726.0         720   1238.0
# 7129267  2004     12          16          4   1336.0        1330   1507.0
# 7129268  2004     12          16          4    538.0         540    720.0
# 7129269  2004     12          16          4    811.0         813    955.0
#
#          CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
Y2005
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0        2005      1          28          5   1603.0        1605   1741.0
# 1        2005      1          29          6   1559.0        1605   1736.0
# 2        2005      1          30          7   1603.0        1610   1741.0
# 3        2005      1          31          1   1556.0        1605   1726.0
# 4        2005      1           2          7   1934.0        1900   2235.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 7140591  2005     12          22          4   1652.0        1655   1815.0
# 7140592  2005     12          22          4   1825.0        1825   1858.0
# 7140593  2005     12          22          4   1507.0        1511   1641.0
# 7140594  2005     12          22          4    924.0         925   1056.0
# 7140595  2005     12          22          4   1345.0        1344   1621.0
#
#          CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
Y2006
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0        2006      1          11          3    743.0         745   1024.0
# 1        2006      1          11          3   1053.0        1053   1313.0
# 2        2006      1          11          3   1915.0        1915   2110.0
# 3        2006      1          11          3   1753.0        1755   1925.0
# 4        2006      1          11          3    824.0         832   1015.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 7141917  2006     12          29          5   1246.0        1249   1452.0
# 7141918  2006     12          29          5   1225.0        1155   2033.0
# 7141919  2006     12          29          5   2118.0        2115   2254.0
# 7141920  2006     12          29          5   2122.0        2127   2209.0
# 7141921  2006     12          29          5   2042.0        2045   2213.0
#
#          CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
Y2007
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0        2007      1           1          1   1232.0        1225   1341.0
# 1        2007      1           1          1   1918.0        1905   2043.0
# 2        2007      1           1          1   2206.0        2130   2334.0
# 3        2007      1           1          1   1230.0        1200   1356.0
# 4        2007      1           1          1    831.0         830    957.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 7453210  2007     12          15          6   1558.0        1605   1749.0
# 7453211  2007     12          15          6   1902.0        1851   2110.0
# 7453212  2007     12          15          6   1024.0        1025   1750.0
# 7453213  2007     12          15          6   1353.0        1315   1658.0
# 7453214  2007     12          15          6   1824.0        1800   2001.0
#
#          CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
df = pd.concat([Y2003, Y2004, Y2005, Y2006, Y2007], ignore_index=True)

# %%
df
# Out:
#           Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0         2003      1          29          3   1651.0        1655   1912.0
# 1         2003      1          30          4   1654.0        1655   1910.0
# 2         2003      1          31          5   1724.0        1655   1936.0
# 3         2003      1           1          3   1033.0        1035   1625.0
# 4         2003      1           2          4   1053.0        1035   1726.0
# ...        ...    ...         ...        ...      ...         ...      ...
# 35353538  2007     12          15          6   1558.0        1605   1749.0
# 35353539  2007     12          15          6   1902.0        1851   2110.0
# 35353540  2007     12          15          6   1024.0        1025   1750.0
# 35353541  2007     12          15          6   1353.0        1315   1658.0
# 35353542  2007     12          15          6   1824.0        1800   2001.0
#
# ...

# %%
df.isnull().sum()
# Out:
# Year                        0
# Month                       0
# DayofMonth                  0
# DayOfWeek                   0
# DepTime                645638
# CRSDepTime                  0
# ArrTime                718196
# CRSArrTime                  0
# UniqueCarrier               0
# FlightNum                   0
# TailNum                 26485
# ActualElapsedTime      718197
# CRSElapsedTime            999
# AirTime                718196
# ArrDelay               718197
# DepDelay               645638
# Origin                      0
# Dest                        0
# Distance                    0
# TaxiIn                      0
# TaxiOut                     0
# Cancelled                   0
# CancellationCode     34756271
# Diverted                    0
# CarrierDelay          2672742
# WeatherDelay          2672742
# NASDelay              2672742
# SecurityDelay         2672742
# LateAircraftDelay     2672742
# dtype: int64

# %%
#saving combined dataset
df.to_csv("C:/Users/Admin/Desktop/ST2195_Programming_for_datascience/Coursework/dataset", index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[22], line 2
#       1 #saving combined dataset
# ----> 2 df.to_csv("C:/Users/Admin/Desktop/ST2195_Programming_for_datascience/Coursework/dataset", index=False)
#
# File c:\Users\Admin\Desktop\ST2195_Programming_for_datascience\Coursework\.venv\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...
